# %% [markdown]
# ### 나의 첫 쥬피터 노트북

# %%
import pandas as pd
df=pd.read_csv("../v027_MiniForge/data/sales.csv")
df
# Out:
#       month  total_sales_krw
# 0   2024-01        100286757
# 1   2024-02         84020387
# 2   2024-03         85356198
# 3   2024-04         81187519
# 4   2024-05         73611082
# 5   2024-06         80523325
# 6   2024-07         80790672
# 7   2024-08         95129409
# 8   2024-09         92963935
# 9   2024-10         75348025
# 10  2024-11         78150399
# 11  2024-12         96067699
